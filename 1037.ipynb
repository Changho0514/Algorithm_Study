# %%
import time

# %%
from IPython.display import Image
Image(filename='/Users/choichangho/Desktop/1037.png')

# %% [markdown]
# # 정답

# %%
n = int(input())
mea = list(map(int, input().split()))
a = min(mea)
b = max(mea)
print(a*b)

# %% [markdown]
# ## 1. 접근 방법

# %% [markdown]
# N에 대한 약수가 모두 주어졌을 때 N의 값을 구하는 문제.
# 이 약수들 중 가장 작은 수와 가장 큰 수를 곱하면 N을 구할 수 있다.

# %% [markdown]
# ## 2. 시행착오.
# 크게 시행착오를 겪진 않았다.
