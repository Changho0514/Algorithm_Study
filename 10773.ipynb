# %%
import time

# %%
from IPython.display import Image
Image(filename='/Users/choichangho/Desktop/10773.png')

# %% [markdown]
# # 정답

# %%
K = int(input())
stack = []

for i in range(K):
    a = int(input())
    if a == 0:
        stack.pop()
    else:
        stack.append(a)

print(sum(stack))
# Out:
# 0

# %% [markdown]
# ## 1. 접근 방법
# - 0이 입력되면 "최근에 입력된 수" 를 지우는 것이 원칙이므로 stack을 쓰는게 중요하다

# %% [markdown]
# ## 2. 시행착오.
