# %%
import time

# %%
from IPython.display import Image
Image(filename='/Users/choichangho/Desktop/1085.png')

# %% [markdown]
# # 정답

# %%
import math
x, y, w, h = map(int, input().split())

near_distance = min((w-x), x, y, (h-y))
print(near_distance)
# Out:
# 347

# %% [markdown]
# ## 1. 접근 방법
#
# 직사각형에서 가장 가까운 변까지의 거리는
# x, y, w-x, h-y이다

# %% [markdown]
# ## 2. 시행착오.
# 크게 시행착오를 겪진 않았다.
