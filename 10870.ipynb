# %%
from IPython.display import Image
Image(filename='/Users/choichangho/Desktop/10870.png')

# %%
def fibonacci(n):
    if n <= 1:
        return n
    return fibonacci(n-1) + fibonacci(n-2)

n = int(input())
print(fibonacci(n))
# Out:
# 55
