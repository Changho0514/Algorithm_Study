# %%
from IPython.display import Image
Image(filename='./10872.png')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /var/folders/9y/vqdb90c5195d4d0sfzm3359c0000gn/T/ipykernel_8929/4024755979.py in <module>
#       1 from IPython.display import Image
# ----> 2 Image(filename='./10872.png')
#
# ~/opt/anaconda3/envs/ch/lib/python3.7/site-packages/IPython/core/display.py in __init__(self, data, url, filename, format, embed, width, height, retina, unconfined, metadata)
#    1230         self.unconfined = unconfined
#    1231         super(Image, self).__init__(data=data, url=url, filename=filename,
# -> 1232                 metadata=metadata)
#    1233
#    1234         if self.width is None and self.metadata.get('width', {}):
#
# ~/opt/anaconda3/envs/ch/lib/python3.7/site-packages/IPython/core/display.py in __init__(self, data, url, filename, metadata)
#     635             self.metadata = {}
#     636
# --> 637         self.reload()
# ...

# %%
n = int(input())

total = 1
for i in range(1, n + 1):
    total *= i

print(total)
# Out:
# 120
