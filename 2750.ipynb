# %%
import time

# %%
from IPython.display import Image
Image(filename='/Users/choichangho/Desktop/2750.png')

# %% [markdown]
# # 정답

# %%
a = [1, 10, 5, 2, 4]
# Out:
# None

# %%
N = int(input())
nums = []
for i in range(N):
    nums.append(int(input()))
nums.sort()
for j in range(len(nums)):
    print(nums[j])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/9y/vqdb90c5195d4d0sfzm3359c0000gn/T/ipykernel_11180/2804681632.py in <module>
# ----> 1 N = int(input())
#       2 nums = []
#       3 for i in range(N):
#       4     nums.append(int(input()))
#       5 nums.sort()
#
# ValueError: invalid literal for int() with base 10: ''

# %% [markdown]
# ## 1. 접근 방법

# %% [markdown]
# ## 2. 시행착오.
# 크게 시행착오를 겪진 않았다.
