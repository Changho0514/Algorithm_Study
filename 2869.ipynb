# %%
from IPython.display import Image
Image(filename='/Users/choichangho/Desktop/2869.png')

# %%
A, B, V = map(int, input().split())

C = A - B # 올라갔다가 미끄러지는 총량
D = V - A # 정상에 오르기 전날의 높이
day = 0
if D % C == 0:
    day = D//C + 1
else:
    day = D//C + 2
print(day)
# Out:
# 99999901
