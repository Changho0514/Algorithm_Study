# %%
from IPython.display import Image
Image(filename='./2941.png')

# %%
croa_alp = ['c=',  'c-', 'dz=','d-', 'lj','nj','s=','z=']
word = input()

for i in croa_alp:
    word = word.replace(i, '*') #input 변수와 동일한 이름의 변수
print(len(word))
# Out:
# 6

# %% [markdown]
# ## 설명
# for문을 돌며 'c=',  'c-', 'dz=','d-', 'lj','nj','s=','z=' 가 각각 존재하면
# replace 함수로 수정한다. '*'은 크로아티아 알파벳 표기에 속하지 않기 때문에 사용이 가능하고,
# replace 함수는 함수를 사용한 문자열 원형을 변형시키지 않는 비파괴적 함수이기 때문에 사용하였다.
